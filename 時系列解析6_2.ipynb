# %% [markdown]
# ## 時系列解析6_2 24時間後予想　うまくいかない
# https://qiita.com/mix_dvd/items/ecfa6f0038e39cdce57e

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.advanced_activations import ELU
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.layers.recurrent import LSTM, GRU
from keras.layers import concatenate
from keras.layers import Input, merge
from keras.layers import Merge
from keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler, ReduceLROnPlateau
from utils import save_model_viz, save_weights, save_hist, plot_hist2
# Out:
# /Users/mitsuhiro/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /Users/mitsuhiro/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
df_kw = pd.read_csv("data/juyo-2017.csv",encoding="Shift_JIS",skiprows=1)
df_kw["MW"] = df_kw["実績(万kW)"] * 10

df_kw["DATETIME"] = df_kw.index.map(lambda x: pd.to_datetime(df_kw.DATE[x] + " " + df_kw.TIME[x]))

# 可視化
df_kw["MW"].plot(figsize=(15,4))

# %%
def read_temp(filename):
    df_temp = pd.read_csv(filename,encoding="Shift_JIS",skiprows=4)
    df_temp.columns = ["DATETIME","TEMP","品質情報","均質番号"]
    df_temp.DATETIME = df_temp.DATETIME.map(lambda _: pd.to_datetime(_))
    return df_temp

# 岡山
df_temp_okym = read_temp("data/data_okayama-2017.csv")
df_temp_okym.rename(columns = {'TEMP':'TEMP_okym'}, inplace=True)

# 広島
df_temp_hrsm = read_temp("data/data_hiroshima-2017.csv")
df_temp_hrsm.rename(columns = {'TEMP':'TEMP_hrsm'}, inplace=True)

# 可視化
df_temp_okym.TEMP_okym.plot(figsize=(15,4))
df_temp_hrsm.TEMP_hrsm.plot(figsize=(15,4))

# %%
len(df_temp_okym), len(df_temp_hrsm),len(df_kw)
# Out:
# (8760, 8760, 8760)

# %%
# データの複製
df = df_kw.copy()
# 岡山の気温を結合
df = df.merge(df_temp_okym,how="inner", on="DATETIME")
# 広島の気温を結合
df = df.merge(df_temp_hrsm,how="inner", on="DATETIME")

df = df.dropna()

# %%
print(df.MW.mean(), df.TEMP_okym.mean(), df.TEMP_hrsm.mean())
print(df.MW.std(), df.TEMP_okym.std(), df.TEMP_hrsm.std())
# Out:
# 7105.1786733645395 15.711485329375469 16.354424021006995
# 1243.3727995382856 9.511011061918847 9.128966280809285

# %%
df_MW = (df.MW - df.MW.mean())/df.MW.std()
df_TEMP_okym =  (df.TEMP_okym - df.TEMP_okym.mean())/df.TEMP_okym.std()
df_TEMP_hrsm =  (df.TEMP_hrsm - df.TEMP_hrsm.mean())/df.TEMP_hrsm.std()

# %%
print(df_MW.mean(), df_TEMP_okym.mean(), df_TEMP_hrsm.mean())
print(df_MW.std(), df_TEMP_okym.std(), df_TEMP_hrsm.std())
# Out:
# 5.569240695967591e-16 2.852762361688383e-15 -2.8559565185807858e-15
# 0.9999999999999958 1.0000000000000044 0.9999999999999978

# %%
def create_dataset(y, x1, x2,  steps_of_history, steps_in_future, predict_future):
    X, X_2, Y = [], [],[]
    for i in range(0, len(y)-steps_of_history - predict_future, steps_in_future):
        X.append([[y[i:i+steps_of_history]] ,[x1[i:i+steps_of_history]], [x2[i:i+steps_of_history]]])  
        X_2.append([[x1[i+ predict_future:i+steps_of_history + predict_future]], [x2[i+ predict_future:i+steps_of_history+ predict_future]]])  
        Y.append(y[i + steps_of_history + predict_future])
    X = np.reshape(np.array(X), [-1, 3, steps_of_history]).transpose(0,2,1)
    X_2 = np.reshape(np.array(X_2), [-1, 2, steps_of_history]).transpose(0,2,1) 
    Y = np.reshape(np.array(Y), [-1, 1])
    return X, X_2, Y

def split_data(x, y, test_size=0.1):
    pos = round(len(x) * (1 - test_size))
    trainX, trainY = x[:pos], y[:pos]
    testX, testY   = x[pos:], y[pos:]
    return trainX, trainY, testX, testY

steps_of_history = 24
steps_in_future = 1
predict_future = 24

X, X_2, Y = create_dataset(df_MW, df_TEMP_okym, df_TEMP_hrsm, steps_of_history, steps_in_future, predict_future)
trainX, trainY, testX, testY = split_data(X, Y, 0.33)
trainX_2, trainY_2, testX_2, testY_2 = split_data(X_2, Y, 0.33)

# %%
print(trainX.shape, trainY.shape,  testX.shape, testY.shape, trainX_2.shape,testX_2.shape)
# Out:
# (5836, 24, 3) (5836, 1) (2875, 24, 3) (2875, 1) (5836, 24, 2) (2875, 24, 2)

# %%
df_MW[0:49], df_TEMP_okym[0:49] , df_TEMP_hrsm[0:49], trainX[0],trainY[0], trainX_2[0]
# Out:
# (0    -0.406297
#  1    -0.205231
#  2    -0.036336
#  3    -0.116762
#  4    -0.349999
#  5    -0.366084
#  6    -0.390212
#  7    -0.173060
#  8     0.132560
#  9    -0.245444
#  10   -0.317828
#  11   -0.671704
#  12   -0.679747
#  13   -0.880813
#  14   -0.848642
#  15   -0.792344
#  16   -0.671704
#  17   -0.285657
#  18   -0.173060
#  19   -0.317828
#  20   -0.518894
#  21   -0.736045
#  22   -0.912983
#  23   -0.937111
#  24   -0.872770
#  25   -0.559107
#  26   -0.341956
#  27   -0.430425
#  28   -0.711917
#  29   -0.824514
#  30   -0.848642
#  31   -1.001452
#  32   -0.961239
#  33   -1.041666
#  34   -1.009495
#  35   -1.081879
#  36   -1.170348
#  37   -1.290987
#  38   -1.355329
#  39   -0.969282
#  40   -0.607363
#  41   -0.317828
#  42   -0.181103
#  43   -0.309785
#  44   -0.470638
#  45   -0.744088
#  46   -0.985367
#  47   -0.921026
#  48   -0.800386
#  Name: MW, dtype: float64, 0    -1.157762
#  1    -1.147248
#  2    -1.136734
#  3    -1.115705
#  4    -1.126219
#  5    -1.147248
#  6    -1.115705
#  7    -0.968507
#  8    -0.800281
#  9    -0.611027
#  10   -0.505886
#  11   -0.337660
#  12   -0.232518
#  13   -0.222004
#  14   -0.106349
#  15   -0.211490
#  16   -0.316631
#  17   -0.358688
#  18   -0.442801
#  19   -0.526914
#  20   -0.684626
#  21   -0.768739
#  22   -0.821310
#  23   -0.947479
#  24   -1.000050
#  25   -1.147248
#  26   -1.178790
#  27   -1.220847
#  28   -1.262903
#  29   -1.304960
#  30   -1.231361
#  31   -1.000050
#  32   -0.674112
#  33   -0.400744
#  34   -0.348174
#  35   -0.200976
#  36   -0.169434
#  37   -0.053778
#         [-0.06429236, -0.56462297],
#         [-0.09583475, -0.70702682],
#         [-0.23251843, -0.72893511],
#         [-0.43228688, -0.70702682],
#         [-0.44280101, -0.72893511],
#         [-0.55845643, -0.72893511],
#         [-0.67411186, -0.79465996],
#         [-0.76873902, -0.81656825],
#         [-0.8318238 , -0.88229311],
#         [-1.02107812, -1.02469696]]))

# %%
CLS_LR = 0.00001
BATCHSIZE = 128
epochs = 100
np.random.seed(1234)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=20, min_lr=0.000001)

model_1 = Sequential()
model_1.add(LSTM(128, return_sequences=False,
                     input_shape=(steps_of_history,3)))
# model_1.add(LSTM(64,return_sequences=False))

model_2 = Sequential()
model_2.add(LSTM(128, return_sequences=False,
                     input_shape=(steps_of_history,2)))
# model_2.add(LSTM(64,return_sequences=False))

model = Sequential()
model.add(Merge([model_1, model_2], mode='concat', concat_axis=1))
model.add(Dense(128))
model.add(Dense(1))
model.add(Activation("linear"))


model.compile(loss='mean_squared_error',optimizer=Adam(lr=CLS_LR))

model.summary()

hist = model.fit([trainX, trainX_2], trainY,
              batch_size=BATCHSIZE,
              epochs=epochs,
              verbose=1,
              validation_data=([testX, testX_2], testY),
              shuffle=True, callbacks=[reduce_lr])
                   
RUN_ID = 'LSTM2'
save_model_viz(RUN_ID, model)
save_weights(RUN_ID, model)
save_hist(RUN_ID, hist)
# Out:
# /Users/mitsuhiro/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/ipykernel/__main__.py:19: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# merge_1 (Merge)              (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 167,681
# Trainable params: 167,681
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5836 samples, validate on 2875 samples
# Epoch 1/200
# 5836/5836 [==============================] - 4s 664us/step - loss: 0.9731 - val_loss: 1.0830
# Epoch 2/200
# 5836/5836 [==============================] - 3s 525us/step - loss: 0.8919 - val_loss: 1.0489
# Epoch 3/200
# 5836/5836 [==============================] - 3s 530us/step - loss: 0.8211 - val_loss: 1.0073
# Epoch 4/200
# 5836/5836 [==============================] - 3s 521us/step - loss: 0.7582 - val_loss: 0.9549
# Epoch 5/200
# 5836/5836 [==============================] - 3s 533us/step - loss: 0.7018 - val_loss: 0.9063
# Epoch 6/200
# 5836/5836 [==============================] - 3s 533us/step - loss: 0.6525 - val_loss: 0.8666
# Epoch 7/200
# 5836/5836 [==============================] - 3s 538us/step - loss: 0.6101 - val_loss: 0.8244
# Epoch 8/200
# 5836/5836 [==============================] - 3s 541us/step - loss: 0.5751 - val_loss: 0.7871
# Epoch 9/200
# 5836/5836 [==============================] - 3s 541us/step - loss: 0.5474 - val_loss: 0.7604
# Epoch 10/200
# 5836/5836 [==============================] - 3s 543us/step - loss: 0.5255 - val_loss: 0.7275
# Epoch 11/200
# 5836/5836 [==============================] - 3s 543us/step - loss: 0.5079 - val_loss: 0.7170
# Epoch 12/200
# 5836/5836 [==============================] - 3s 547us/step - loss: 0.4923 - val_loss: 0.6823
# Epoch 13/200
# 5836/5836 [==============================] - 3s 543us/step - loss: 0.4785 - val_loss: 0.6547
# Epoch 14/200
# 5836/5836 [==============================] - 3s 563us/step - loss: 0.4651 - val_loss: 0.6341
# 5836/5836 [==============================] - 3s 575us/step - loss: 0.1717 - val_loss: 0.3816
# Epoch 185/200
# 5836/5836 [==============================] - 3s 571us/step - loss: 0.1718 - val_loss: 0.3829
# Epoch 186/200
# 5836/5836 [==============================] - 3s 587us/step - loss: 0.1716 - val_loss: 0.3823
# Epoch 187/200
# 5836/5836 [==============================] - 3s 578us/step - loss: 0.1717 - val_loss: 0.3822
# Epoch 188/200
# 5836/5836 [==============================] - 3s 573us/step - loss: 0.1717 - val_loss: 0.3825
# Epoch 189/200
# 5836/5836 [==============================] - 3s 577us/step - loss: 0.1716 - val_loss: 0.3830
# Epoch 190/200
# 5836/5836 [==============================] - 3s 583us/step - loss: 0.1715 - val_loss: 0.3838
# Epoch 191/200
# 5836/5836 [==============================] - 3s 574us/step - loss: 0.1715 - val_loss: 0.3835
# Epoch 192/200
# 5836/5836 [==============================] - 3s 570us/step - loss: 0.1714 - val_loss: 0.3832
# Epoch 193/200
# 5836/5836 [==============================] - 3s 583us/step - loss: 0.1714 - val_loss: 0.3835
# Epoch 194/200
# 5836/5836 [==============================] - 3s 579us/step - loss: 0.1714 - val_loss: 0.3833
# Epoch 195/200
# 5836/5836 [==============================] - 3s 579us/step - loss: 0.1714 - val_loss: 0.3833
# Epoch 196/200
# 5836/5836 [==============================] - 3s 580us/step - loss: 0.1714 - val_loss: 0.3830
# Epoch 197/200
# 5836/5836 [==============================] - 3s 572us/step - loss: 0.1714 - val_loss: 0.3834
# Epoch 198/200
# 5836/5836 [==============================] - 3s 573us/step - loss: 0.1714 - val_loss: 0.3831
# Epoch 199/200
# 5836/5836 [==============================] - 3s 578us/step - loss: 0.1714 - val_loss: 0.3836
# Epoch 200/200
# 5836/5836 [==============================] - 3s 576us/step - loss: 0.1713 - val_loss: 0.3835

# %%
plot_hist2(RUN_ID)

# %%
# 二乗平方根で誤差を算出
from sklearn.metrics import mean_squared_error

# 予測値の取得
y_pred = model.predict([testX, testX_2])
mse = mean_squared_error(testY*df.MW.std() + df.MW.mean(),y_pred*df.MW.std() + df.MW.mean() )
print("KERAS REG RMSE : %.2f" % (mse ** 0.5))

# 可視化
plt.figure(figsize=(30, 10))
plt.plot(testY*df.MW.std() + df.MW.mean(), label='truth')
plt.plot(y_pred*df.MW.std() + df.MW.mean() , label='pred')
# Out:
# KERAS REG RMSE : 769.96

# %% [markdown]
# # 2017年から2018年を予測

# %%
df_kw_18 = pd.read_csv("data/juyo-2018.csv",encoding="Shift_JIS",skiprows=1)
df_kw_18["MW"] = df_kw_18["実績(万kW)"] * 10

df_kw_18["DATETIME"] = df_kw_18.index.map(lambda x: pd.to_datetime(df_kw_18.DATE[x] + " " + df_kw_18.TIME[x]))

# 可視化
df_kw_18["MW"].plot(figsize=(15,4))

# %%
def read_temp(filename):
    df_temp = pd.read_csv(filename,encoding="Shift_JIS",skiprows=4)
    df_temp.columns = ["DATETIME","TEMP","品質情報","均質番号"]
    df_temp.DATETIME = df_temp.DATETIME.map(lambda _: pd.to_datetime(_))
    return df_temp

# 岡山
df_temp_okym_18 = read_temp("data/data_okayama-2018.csv")
df_temp_okym_18.rename(columns = {'TEMP':'TEMP_okym'}, inplace=True)

# 広島
df_temp_hrsm_18 = read_temp("data/data_hiroshima-2018.csv")
df_temp_hrsm_18.rename(columns = {'TEMP':'TEMP_hrsm'}, inplace=True)

# 可視化
df_temp_okym_18.TEMP_okym.plot(figsize=(15,4))
df_temp_hrsm_18.TEMP_hrsm.plot(figsize=(15,4))

# %%
# データの複製
df_18 = df_kw_18.copy()
# 岡山の気温を結合
df_18= df_18.merge(df_temp_okym_18,how="inner", on="DATETIME")
# 広島の気温を結合
df_18 = df_18.merge(df_temp_hrsm_18,how="inner", on="DATETIME")

df_18 = df_18.dropna()

# %%
df_MW_18 = (df_18.MW - df_18.MW.mean())/df_18.MW.std()
df_TEMP_okym_18 =  (df_18.TEMP_okym - df_18.TEMP_okym.mean())/df_18.TEMP_okym.std()
df_TEMP_hrsm_18 =  (df_18.TEMP_hrsm - df_18.TEMP_hrsm.mean())/df_18.TEMP_hrsm.std()

# %%
def create_dataset(y, x1, x2,  steps_of_history, steps_in_future, predict_future):
    X, X_2, Y = [], [],[]
    for i in range(0, len(y)-steps_of_history - predict_future, steps_in_future):
        X.append([[y[i:i+steps_of_history]] ,[x1[i:i+steps_of_history]], [x2[i:i+steps_of_history]]])  
        X_2.append([[x1[i+ predict_future:i+steps_of_history + predict_future]], [x2[i+ predict_future:i+steps_of_history+ predict_future]]])  
        Y.append(y[i + steps_of_history + predict_future])
    X = np.reshape(np.array(X), [-1, 3, steps_of_history]).transpose(0,2,1)
    X_2 = np.reshape(np.array(X_2), [-1, 2, steps_of_history]).transpose(0,2,1) 
    Y = np.reshape(np.array(Y), [-1, 1])
    return X, X_2, Y

def split_data(x, y, test_size=0.1):
    pos = round(len(x) * (1 - test_size))
    trainX, trainY = x[:pos], y[:pos]
    testX, testY   = x[pos:], y[pos:]
    return trainX, trainY, testX, testY

X_18, X_2_18, Y_18 = create_dataset(df_MW_18, df_TEMP_okym_18, df_TEMP_hrsm_18, steps_of_history, steps_in_future, predict_future)

# %%
# 二乗平方根で誤差を算出
from sklearn.metrics import mean_squared_error

# 予測値の取得
y_pred_18 = model.predict([X_18, X_2_18])
mse = mean_squared_error(Y_18*df_18.MW.std() + df_18.MW.mean(),y_pred_18*df_18.MW.std() + df_18.MW.mean() )
print("KERAS REG RMSE : %.2f" % (mse ** 0.5))

# 可視化
plt.figure(figsize=(30, 10))
plt.plot(Y_18[0:1000]*df_18[0:1000].MW.std() + df_18[0:1000].MW.mean(), label='truth')
plt.plot(y_pred_18[0:1000]*df_18[0:1000].MW.std() + df_18[0:1000].MW.mean() , label='pred')
# Out:
# KERAS REG RMSE : 598.37

# %%
# 可視化
plt.figure(figsize=(30, 10))
plt.plot(Y_18[1000:2000]*df_18[1000:2000].MW.std() + df_18[1000:2000].MW.mean(), label='truth')
plt.plot(y_pred_18[1000:2000]*df_18[1000:2000].MW.std() + df_18[1000:2000].MW.mean() , label='pred')
